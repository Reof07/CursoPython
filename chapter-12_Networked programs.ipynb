# %% [markdown]
# # Chapter-12 : Networked programs

# %% [markdown]
# ## Hypertext Transfer Protocol - HTTP
#
# python integra un soporte integrado llamado **socket** para hacer conexiones de red y recuperar datos a travez de esos sockets mediante un programa en pyhton.
#
# Un socket es muy parecido a un archivo, excepto que un solo socket proporciona una conexion bidireccional entre dos programas. puedes leer y escribir el mismo socket. Si escribes algo en un socket, se envia a la aplicación en el otro extremo del socket. y si leemos desde el socket, recibiras los datos que ha enviado la otra aplicación.
#
# Sin intentamos leer datos de un socket  el otro extremo no ha enviado ningun dato, simplemente se sienta a esperar. Lo mas impotante de los programas qu se comunican por internet es tener algun protocolo.

# %% [markdown]
# ## The world's simplest web browser
#
# Quizas la forma mas simple de entender como funcionan los protocolos http, es esccribiendo un simple programa en python que se conecte a un servidor web y muestre lo que el servidor envia de vuelta.

# %%
import socket # importamos la libreria socket.

#
mySock = socket.socket(socket.AF_INET,socket.SOCK_STREAM) 

# hacemos conexion por el puerto 80 en el servidor.
mySock.connect(('data.pr4e.org',80))

#               
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()

#               
mySock.send(cmd)
               
while True:
    data = mySock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(), end = '')

mySock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Tue, 31 Mar 2020 23:34:26 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %% [markdown]
# ## Retrieving an image over HTTP

# %%
import socket
import time

HOST = 'data.pr4e.org'
PORT = 80
mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect((HOST, PORT))
mysock.sendall(b'GET http://data.pr4e.org/cover3.jpg HTTP/1.0\r\n\r\n')
count = 0
picture = b""

while True:
    data = mysock.recv(5120)
    if len(data) < 1: break
    #time.sleep(0.25)
    count = count + len(data)
    print(len(data), count)
    picture = picture + data

mysock.close()

# Look for the end of the header (2 CRLF)
pos = picture.find(b"\r\n\r\n")
print('Header length', pos)
print(picture[:pos].decode())

# Skip past the header and save the picture data
picture = picture[pos+4:]
fhand = open("stuff.jpg", "wb")
fhand.write(picture)
fhand.close()
# Out:
# 1448 1448
# 1448 2896
# 1448 4344
# 1448 5792
# 1448 7240
# 1448 8688
# 1448 10136
# 1448 11584
# 1448 13032
# 1448 14480
# 2896 17376
# 1448 18824
# 1448 20272
# 1448 21720
# 1448 23168
# 1448 24616
# 1448 26064
# 2896 28960
# 1448 30408
# 5120 35528
# 5016 40544
# 1448 41992
# 1448 43440
# 1448 44888
# 1448 46336
# 1448 47784
# 1448 49232
# 1448 50680
# 1448 52128
# 1448 53576
# 1448 55024
# 1448 56472
# 5120 61592
# 5120 66712
# 2792 69504
# 1448 70952
# 1448 72400
# 5120 77520
# 5120 82640
# 2792 85432
# 1448 86880
# 5120 92000
# 5120 97120
# 4240 101360
# 1448 102808
# 5120 107928
# 5016 112944
# 1448 114392
# 1448 115840
# 1448 117288
# 1448 118736
# 1448 120184
# 1448 121632
# 1448 123080
# 1448 124528
# 1448 125976
# 1448 127424
# 1448 128872
# 1448 130320
# 1448 131768
# 1448 133216
# 1448 134664
# 1448 136112
# 1448 137560
# 1448 139008
# 1448 140456
# 1448 141904
# 1448 143352
# 4344 147696
# 1448 149144
# 5120 154264
# 2120 156384
# 1448 157832
# 1448 159280
# 5120 164400
# 3568 167968
# 4344 172312
# 1448 173760
# 1448 175208
# 5120 180328
# 672 181000
# 1448 182448
# 1448 183896
# 1448 185344
# 1448 186792
# 1448 188240
# 1448 189688
# 1448 191136
# 1448 192584
# 1448 194032
# 1448 195480
# 1448 196928
# 1448 198376
# 1448 199824
# 1448 201272
# 1448 202720
# 1448 204168
# 1448 205616
# 1448 207064
# 1448 208512
# 1448 209960
# 1448 211408
# 1448 212856
# 1448 214304
# 1448 215752
# 1448 217200
# 1448 218648
# 1448 220096
# 1448 221544
# 1448 222992
# 1448 224440
# 1448 225888
# 1448 227336
# 1448 228784
# 1448 230232
# 376 230608
# Header length 394
# HTTP/1.1 200 OK
# Date: Tue, 31 Mar 2020 23:34:27 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Mon, 15 May 2017 12:27:40 GMT
# ETag: "38342-54f8f2e5b6277"
# Accept-Ranges: bytes
# Content-Length: 230210
# Vary: Accept-Encoding
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: image/jpeg

# %% [markdown]
# ## Retrieving web pages with urllib

# %% [markdown]
# Usando la libreria **urllib** podemos tratar una pagina web como un archivo. simplemente  indicamos que pagina web desearia recuperar y **urllib** maneja todos los detalles del protocollo HTTP y de los encabezados.
#
# El codigo equivalente para leer **romeo.txt** desde la web usando urllib es el siguiente:

# %%
# importamos la libreria (el metodo .request)
import urllib.request

# indicamos la url de la web que deseamos recuperar.
fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %% [markdown]
# Como ejemplo, podemos escribir un programa que recive la data de romeo.txt and cuente la frecuencia de cada palabra en el archivo.

# %%
# importamos los metodos de la libreria urllib
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

counts = dict()
for line in fhand:
    words = line.decode().split()
    for word in words:
        counts[word] = counts.get(word,0)+1

print(counts)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %% [markdown]
# ## Reading binary files using urllib

# %% [markdown]
# Algunas veces queremos recivir un archivo non-text( o binario) como una imagen o video file. la data en estos casos no es util para imprimir, pero podemos facilmente hacer una copia de la url a un archivo local en nuestro disco duro con urllib.
#
# El patron es abrir la url y usar leer para descargar todo el contenido del documento en una variable string (img) y luego escribir esa informacion en un archivo local de la siguiente manera:

# %%
import urllib.request, urllib.parse, urllib.error

img = urllib.request.urlopen('http://data.pr4e.org/cover3.jpg')
fhand = open('cover3.jpg', 'wb')
size = 0
while True:
    info = img.read(100000)
    if len(info) < 1: break
    size = size + len(info)
    fhand.write(info)


print(size, 'characters copied.')
fhand.close()
# Out:
# 230210 characters copied.

# %% [markdown]
# ## Parsing HTML and scraping the web

# %% [markdown]
# Una de los usos mas comunes de la libreria **urllib** es hacer scrape de la web. la web scraping es cuando escribimos un programa que pretende ser un web browser y recibir paginas, entonces examina los datos de estas paginas buscando modelos.

# %% [markdown]
# ## Parsing HTML using regular expressions

# %% [markdown]
# Una de las formas para analizar HTML is usar expresiones regulares para buscar y extraer cadenas que coinciden con un patron en particular.

# %%
# Search for link values within URL input
import urllib.request, urllib.parse, urllib.error
import re
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url).read()
links = re.findall(b'href="(http[s]?://.*?)"', html)
for link in links:
    print(link.decode())
# Out:
# Enter - https://resultados.as.com/
# https://resultados.as.com/resultados/
# https://as.com
# https://resultados.as.com/resultados/
# https://as.com/futbol/
# https://as.com/motor/
# https://as.com/baloncesto/
# https://as.com/tenis/
# https://as.com/ciclismo/
# https://as.com/opinion/
# https://as.com/tag/mundial_2022/a/
# https://esports.as.com/
# https://as.com/ascolor/
# https://as.com/videos/
# https://as.com/tag/albumes/a/
# https://as.com/diarioas/otras_webs_de_as.html
# https://asfan.as.com/conectar?backURL=%2F%2Fresultados.as.com%2Fresultados%2F&prod=REG&o=CABAS
# https://asfan.as.com/registro?backURL=%2F%2Fresultados.as.com%2Fresultados%2F&prod=REG&o=CABAS
# http://arabia.as.com
# https://asfan.as.com/conectar?backURL=%2F%2Fresultados.as.com%2Fresultados%2F&prod=REG&o=CABAS
# https://asfan.as.com/registro?backURL=%2F%2Fresultados.as.com%2Fresultados%2F&prod=REG&o=CABAS
# https://as.com/diarioas/2020/03/31/actualidad/1585628123_622265.html
# https://as.com/diarioas/2020/03/31/actualidad/1585641693_897712.html
# https://mexico.as.com/mexico/2020/03/30/tikitakas/1585578603_567991.html
# https://chile.as.com/chile/2020/03/31/tikitakas/1585651496_361440.html
# https://argentina.as.com/argentina/2020/03/31/tikitakas/1585643445_129930.html
# https://colombia.as.com/colombia/2020/03/31/tikitakas/1585653058_037027.html
# https://peru.as.com/peru/2020/03/31/tikitakas/1585644535_171750.html
# https://us.as.com/us/2020/03/31/tikitakas/1585666280_009500.html
# https://en.as.com/en/2020/03/31/other_sports/1585634639_996639.html
# https://as.com/diarioas/2020/03/31/actualidad/1585634609_506828.html
# https://as.com/diarioas/2020/03/31/actualidad/1585649223_825444.html
# https://as.com/tikitakas/2020/03/27/reportajes/1585332580_086339.html
# https://as.com/masdeporte/2020/03/31/polideportivo/1585611819_948481.html
# https://as.com/masdeporte/2020/03/31/polideportivo/1585616063_549989.html
# https://resultados.as.com/resultados/futbol/champions/jornada/
# https://as.com/masdeporte/2019/12/28/polideportivo/1577560627_356865.html
# https://as.com/tenis/2020/03/11/copa_davis/1583950895_166466.html
# https://resultados.as.com/resultados/motor/formula_1/2020/calendario/
# https://resultados.as.com/resultados/motor/motogp/2020/calendario/
# https://as.com/especiales/futbol/eurocopa/2020/calendario-dias/
# https://resultados.as.com/resultados/futbol/champions/calendario/
# https://resultados.as.com/resultados/futbol/primera/calendario/
# https://resultados.as.com/resultados/futbol/segunda/calendario/
# https://resultados.as.com/resultados/futbol/copa_del_rey/calendario/
# https://resultados.as.com/resultados/futbol/segunda_b/
# https://resultados.as.com/resultados/futbol/copa_libertadores/calendario/
# https://as.com/baloncesto/2019/08/16/acb/1565955625_999562.html
# https://resultados.as.com/resultados/futbol/primera/clasificacion/
# https://resultados.as.com/resultados/futbol/segunda/clasificacion/
# https://as.com/tag/formula_1/a/
# https://as.com/tag/moto_gp/a/
# https://resultados.as.com/quiniela/
# https://as.com/tag/fichajes/a/
# https://as.com/tag/partidos_futbol/a/
# https://as.com/tag/horarios_partidos/a/
# https://as.com/tag/fecha/ultimahora/
# https://as.com/tag/fecha/hoy/
# https://as.com/actualidad/index.html
# https://as.com/diarioas/2020/03/31/actualidad/1585643407_324194.html
# https://as.com/diarioas/2020/03/31/actualidad/1585643345_356462.html
# https://as.com/diarioas/2020/03/31/actualidad/1585643325_750155.html
# https://as.com/diarioas/2020/03/31/actualidad/1585645965_521938.html
# https://as.com/diarioas/2020/03/31/actualidad/1585643407_324194.html
# https://as.com/diarioas/2020/03/31/actualidad/1585655572_602221.html
# https://as.com/meristation/2020/03/31/noticias/1585639743_649150.html
# https://as.com/diarioas/2020/03/31/actualidad/1585664742_317268.html
# https://as.com/diarioas/2020/03/31/actualidad/1585672519_771471.html
# https://mexico.as.com/mexico/2020/03/31/tikitakas/1585673146_606406.html
# https://as.com/futbol/2020/03/31/primera/1585672901_275709.html
# https://as.com/diarioas/2020/03/31/actualidad/1585674525_284685.html
# https://as.com/diarioas/2020/03/31/actualidad/1585677838_239435.html
# https://as.com/diarioas/2020/03/31/actualidad/1585667222_663375.html
# https://as.com/diarioas/2020/03/31/actualidad/1585676211_829154.html
# http://usuarios.as.com/newsletters/
# http://suscripciones.as.com/
# https://as.com/?nrd=1
# https://chile.as.com/chile/?nrd=1
# https://colombia.as.com/colombia/?nrd=1
# https://mexico.as.com/mexico/?nrd=1
# https://us.as.com/us/?nrd=1
# https://argentina.as.com/argentina/?nrd=1
# https://peru.as.com/peru/?nrd=1
# http://arabia.as.com
# https://as.com/?nrd=1
# https://chile.as.com/chile/?nrd=1
# https://colombia.as.com/colombia/?nrd=1
# https://mexico.as.com/mexico/?nrd=1
# https://us.as.com/us/?nrd=1
# https://argentina.as.com/argentina/?nrd=1
# https://peru.as.com/peru/?nrd=1
# https://as.com/diarioas/america.html?nrd=1
# https://en.as.com/en/?nrd=1
# https://arabia.as.com
# https://as.com/movil/app_as.html
# https://www.facebook.com/as
# https://twitter.com/diarioas
# https://plus.google.com/110273731699649425837
# https://www.youtube.com/DIARIOAScom
# https://www.instagram.com/diarioas/
# https://as.com/formularios/contacto.pl
# https://as.com/diarioas/aviso_legal.html
# https://as.com/diarioas/politica_privacidad.html
# https://www.prisa.com/es/info/politica-de-cookies-publi
# https://www.prisabs.com/uploads/2019/04/as-tarifas2019.pdf
# https://as.com/pdf/Condiciones_Generales_Suscripciones_DIARIO_AS.pdf
# https://www.prisa.com/es
# https://elpais.com/
# https://los40.com
# https://www.santillana.com/
# https://santillanacompartir.com/
# https://tvi.iol.pt/
# https://cadenaser.com
# https://as.com/
# http://www.adnradio.cl
# http://caracol.com.co/
# https://www.huffingtonpost.es/
# https://mx.unoi.com/
# http://wradio.com.mx/
# https://cincodias.elpais.com/
# http://www.continental.com.ar
# https://elpais.com/elpais/eps.html
# https://verne.elpais.com/
# https://www.cadenadial.com/
# https://play.kebuena.es/
# https://www.podiumpodcast.com/
# http://www.richmondelt.com/
# https://www.moderna.com.br/pagina-inicial.htm
# http://pluralportugal.pt/
# https://tvi24.iol.pt/
# https://elpais.com/elpais/icon.html
# https://smoda.elpais.com/
# https://www.loqueleo.com/
# https://as.com/meristation/
# https://elpais.com/elpais/planeta_futuro.html
# http://radiocomercial.iol.pt/
# https://www.santillana.com/
# http://www.santillana.com.ar
# https://santillana.com.bo/
# https://www.santillana.com.br/portal-santillana.htm
# https://santillana.cl/
# https://santillana.com.co/
# https://santillana.cr/
# https://santillana.com.ec/
# https://santillana.com.sv/
# https://santillana.es/
# https://santillana.com.gt/
# https://santillana.com.hn/
# https://www.santillana.com.mx/
# https://santillana.com.pa/
# http://www.santillana.com.py/
# https://santillana.com.pe/
# https://www.santillana.pt/
# http://santillana.com.pr/
# https://santillana.com.do/
# https://santillana.com.uy/
# http://www.santillana.com.ve/
# https://www.loqueleo.com/
# http://www.richmondelt.com/
# http://www.santillanafrancais.com/
# https://mx.unoi.com/
# https://santillanacompartir.com/
# https://ineverycrea.net/comunidad/ineverycrea
# https://www.bejob.com/
# https://www.fundacaosantillana.org.br/
# http://www.fundacionsantillana.com/
# http://www.fundacionsantillana.com/paises/colombia/
# http://www.periodismocultural.es/
# http://www.foroindustriasculturales.org/
# http://www.essayandscience.com
# https://www.premiovivalectura.org.ar/
# http://www.elboomeran.com/
# https://www.prisa.com/es/info/noticias
# https://elpais.com/
# https://elpais.com/elpais/portada_america.html?nrd=1
# https://brasil.elpais.com/?nrd=1
# https://cat.elpais.com/?nrd=1
# https://elpais.com/elpais/inenglish.html
# https://elpais.com/elpais/videos.html
# https://elpais.com/cultura/babelia.html
# https://elpais.com/elpais/blogs.html
# https://elpais.com/elpais/buenavida.html
# https://colecciones.elpais.com/
# https://servicios.elpais.com/clasificados/
# https://descuentos.elpais.com/
# https://cursos.elpais.com/
# https://elcomidista.elpais.com/
# https://elviajero.elpais.com/
# http://suscripciones.elpais.com/
# https://elpais.com/elpais/eps.html
# https://www.elpaisviajes.com/
# https://motor.elpais.com/
# https://elpais.com/elpais/escaparate.html
# https://escuela.elpais.com/
# https://elpais.com/elpais/icon.html
# https://elpais.com/elpais/icon_design.html
# https://juegos.elpais.com/?arkpromo=Footer
# https://librotea.elpais.com/
# https://elpais.com/elpais/planeta_futuro.html
# https://verne.elpais.com/
# https://retina.elpais.com/
# https://smoda.elpais.com/
# https://servicios.elpais.com/sorteos/
# https://as.com/?nrd=1
# https://as.com/diarioas/america.html?nrd=1
# https://arabia.as.com/?nrd=1
# https://argentina.as.com/?nrd=1
# https://chile.as.com/?nrd=1
# https://colombia.as.com/?nrd=1
# https://en.as.com/?nrd=1
# https://mexico.as.com/?nrd=1
# https://peru.as.com/?nrd=1
# https://us.as.com/?nrd=1
# https://resultados.as.com/resultados/
# https://as.com/videos/
# https://as.com/tikitakas/
# https://as.com/epik/
# https://as.com/meristation/betech.html
# https://as.com/showroom/
# https://as.com/diarioas/promociones.html
# https://as.com/diarioas/concursos.html
# https://asventajas.com/
# https://cincodias.elpais.com/
# https://cincodias.elpais.com/seccion/companias
# https://cincodias.elpais.com/seccion/mercados
# https://cincodias.elpais.com/seccion/economia
# https://cincodias.elpais.com/seccion/midinero
# https://cincodias.elpais.com/seccion/fortunas
# https://cincodias.elpais.com/mercados/
# https://cincodias.elpais.com/smartlife
# https://cincodias.elpais.com/territorio_pyme
# https://cincodias.elpais.com/agr/legal
# https://www.huffingtonpost.es/
# https://as.com/meristation/
# https://as.com/meristation/mexico.html
# https://www.prisa.com/es/info/radio
# http://www.adnradio.cl/
# https://cadenaser.com/
# http://caracol.com.co/
# http://envivo.caracol1260.com/
# http://www.continental.com.ar/
# http://www.radiopanama.com.pa/
# http://www.wradio.com.co/
# http://wradio.com.mx/
# http://www.wdeportes.com/
# http://los40.com.ar/
# http://los40.cl/
# http://los40.com.co/
# http://los40.co.cr/
# https://los40.com
# http://los40.com.mx/
# http://los40.com.pa/
# http://www.los40.com.py/
# http://www.los40.do/
# https://los40.com/seccion/los40classic/
# https://los40.com/seccion/los40dance/
# http://www.besame.fm/
# http://www.besame.com.pa/
# https://www.cadenadial.com/
# https://www.concierto.cl/
# https://www.corazon.cl/
# https://www.fmdos.cl/
# https://www.futuro.cl/
# https://play.kebuena.es/
# http://www.kebuena.com.mx/
# https://www.masmusica.com.pa/
# http://www.oxigeno.fm/
# http://www.pudahuel.cl/
# http://www.qhuboradio.com/
# http://www.radioacktiva.com/
# http://www.radioactiva.cl/
# https://www.radioimagina.cl/
# https://envivo.radiounochile.cl/
# https://www.radiole.com/
# https://www.rockandpop.cl/
# https://www.tropicanafm.com/bogota/
# http://www.planetevents.es/
# https://www.podiumpodcast.com/
# https://www.prisa.com/es/info/audiovisual
# https://www.mediacapital.pt/
# https://tvi.iol.pt/
# https://tvi24.iol.pt/
# https://tvi.iol.pt/internacional
# https://tvi.iol.pt/tvificcao
# https://tvi.iol.pt/tvireality
# https://tvi.iol.pt/tviafrica
# https://tviplayer.iol.pt/
# http://pluralportugal.pt/
# http://radiocomercial.iol.pt
# http://m80.iol.pt
# http://smoothfm.iol.pt/
# http://cidade.iol.pt/
# http://www.vodafone.fm/
# https://www.iol.pt/
# https://maisfutebol.iol.pt/
# https://autoportal.iol.pt/
# https://www.iol.pt/blogs
# https://www.iolnegocios.pt/
# https://www.prisa.com/es
# http://toyoutome.es/
# https://www.prisabs.com/es

# %% [markdown]
# ##  Parsing HTML using BeautifulSoup

# %%
#Importar las librerias.
import urllib.request, urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url,context=ctx).read()
soup = BeautifulSoup(html,'lxml')

# Retrieve all of the anchor tags

tags = soup('a')
for tag in tags:
    print(tag.get('href',None))
# Out:
# Enter - https://resultados.as.com/
# #menu
# https://as.com
# https://resultados.as.com/resultados/
# https://as.com/futbol/
# https://as.com/motor/
# https://as.com/baloncesto/
# https://as.com/tenis/
# https://as.com/ciclismo/
# //as.com/masdeporte/
# https://as.com/opinion/
# https://as.com/tag/mundial_2022/a/
# https://esports.as.com/
# https://as.com/ascolor/
# https://as.com/videos/
# https://as.com/tag/albumes/a/
# https://as.com/diarioas/otras_webs_de_as.html
# #resultados
# //usuarios.as.com/newsletters/
# #conecta
# #buscador
# #ediciones
# https://asfan.as.com/conectar?backURL=%2F%2Fresultados.as.com%2Fresultados%2F&prod=REG&o=CABAS
# https://asfan.as.com/registro?backURL=%2F%2Fresultados.as.com%2Fresultados%2F&prod=REG&o=CABAS
# //as.com/?nrd=1
# //chile.as.com/chile/?nrd=1
# //colombia.as.com/colombia/?nrd=1
# //mexico.as.com/mexico/?nrd=1
# //us.as.com/us/?nrd=1
# //argentina.as.com/argentina/?nrd=1
# //peru.as.com/peru/?nrd=1
# //as.com/diarioas/america.html?nrd=1
# //en.as.com/en/?nrd=1
# http://arabia.as.com
# https://asfan.as.com/conectar?backURL=%2F%2Fresultados.as.com%2Fresultados%2F&prod=REG&o=CABAS
# https://asfan.as.com/registro?backURL=%2F%2Fresultados.as.com%2Fresultados%2F&prod=REG&o=CABAS
# //as.com/tag/listado/
# https://as.com/diarioas/2020/03/31/actualidad/1585628123_622265.html
# https://as.com/diarioas/2020/03/31/actualidad/1585641693_897712.html
# https://mexico.as.com/mexico/2020/03/30/tikitakas/1585578603_567991.html
# https://chile.as.com/chile/2020/03/31/tikitakas/1585651496_361440.html
# https://argentina.as.com/argentina/2020/03/31/tikitakas/1585643445_129930.html
# https://colombia.as.com/colombia/2020/03/31/tikitakas/1585653058_037027.html
# https://peru.as.com/peru/2020/03/31/tikitakas/1585644535_171750.html
# https://us.as.com/us/2020/03/31/tikitakas/1585666280_009500.html
# https://en.as.com/en/2020/03/31/other_sports/1585634639_996639.html
# https://as.com/diarioas/2020/03/31/actualidad/1585634609_506828.html
# https://as.com/diarioas/2020/03/31/actualidad/1585649223_825444.html
# https://as.com/tikitakas/2020/03/27/reportajes/1585332580_086339.html
# https://as.com/masdeporte/2020/03/31/polideportivo/1585611819_948481.html
# https://as.com/masdeporte/2020/03/31/polideportivo/1585616063_549989.html
# https://resultados.as.com/resultados/futbol/champions/jornada/
# https://as.com/masdeporte/2019/12/28/polideportivo/1577560627_356865.html
# https://as.com/tenis/2020/03/11/copa_davis/1583950895_166466.html
# https://resultados.as.com/resultados/motor/formula_1/2020/calendario/
# https://resultados.as.com/resultados/motor/motogp/2020/calendario/
# https://as.com/especiales/futbol/eurocopa/2020/calendario-dias/
# https://resultados.as.com/resultados/futbol/champions/calendario/
# https://resultados.as.com/resultados/futbol/primera/calendario/
# https://resultados.as.com/resultados/futbol/segunda/calendario/
# https://resultados.as.com/resultados/futbol/copa_del_rey/calendario/
# https://resultados.as.com/resultados/futbol/segunda_b/
# https://resultados.as.com/resultados/futbol/copa_libertadores/calendario/
# https://as.com/baloncesto/2019/08/16/acb/1565955625_999562.html
# https://resultados.as.com/resultados/futbol/primera/clasificacion/
# https://resultados.as.com/resultados/futbol/segunda/clasificacion/
# https://as.com/tag/formula_1/a/
# https://as.com/tag/moto_gp/a/
# https://resultados.as.com/quiniela/
# https://as.com/tag/fichajes/a/
# https://as.com/tag/partidos_futbol/a/
# https://as.com/tag/horarios_partidos/a/
# https://as.com/tag/fecha/ultimahora/
# https://as.com/tag/fecha/hoy/
# https://as.com/actualidad/index.html
# https://as.com/diarioas/2020/03/31/actualidad/1585643407_324194.html
# https://as.com/diarioas/2020/03/31/actualidad/1585643345_356462.html
# https://as.com/diarioas/2020/03/31/actualidad/1585643325_750155.html
# https://as.com/diarioas/2020/03/31/actualidad/1585645965_521938.html
# https://as.com/diarioas/2020/03/31/actualidad/1585643407_324194.html
# https://as.com/diarioas/2020/03/31/actualidad/1585655572_602221.html
# https://as.com/meristation/2020/03/31/noticias/1585639743_649150.html
# https://as.com/diarioas/2020/03/31/actualidad/1585664742_317268.html
# https://as.com/diarioas/2020/03/31/actualidad/1585672519_771471.html
# https://mexico.as.com/mexico/2020/03/31/tikitakas/1585673146_606406.html
# https://as.com/futbol/2020/03/31/primera/1585672901_275709.html
# https://as.com/diarioas/2020/03/31/actualidad/1585674525_284685.html
# https://as.com/diarioas/2020/03/31/actualidad/1585677838_239435.html
# https://as.com/diarioas/2020/03/31/actualidad/1585667222_663375.html
# https://as.com/diarioas/2020/03/31/actualidad/1585676211_829154.html
# javascript:void(0);
# //resultados.as.com/resultados/?omnil=src-sab
# //as.com/futbol/?omnil=src-sab
# //as.com/motor/?omnil=src-sab
# //as.com/baloncesto/?omnil=src-sab
# //as.com/tenis/?omnil=src-sab
# //as.com/ciclismo/?omnil=src-sab
# //as.com/masdeporte/?omnil=src-sab
# //as.com/ascolor/?omnil=src-sab
# //as.com/tag/mundial_2022/a/?omnil=src-sab
# //esports.as.com/?omnil=src-sab
# //as.com/videos/?omnil=src-sab
# //as.com/tag/albumes/a/?omnil=src-sab
# //as.com/tag/c/16a24b31b9237e6cbbc325e1e810eb0b/?omnil=src-sab
# //as.com/tag/reportajes/a/?omnil=src-sab
# //as.com/opinion/?omnil=src-sab
# //as.com/diarioas/otras_webs_de_as.html?omnil=src-sab
# //as.com/diarioas/portadas/?omnil=src-sab
# //as.com/estaticos/aviso_legal.html?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/primera/?omnil=src-sab
# //resultados.as.com/resultados/futbol/segunda/?omnil=src-sab
# //resultados.as.com/resultados/futbol/segunda_b/?omnil=src-sab
# //resultados.as.com/resultados/futbol/tercera/?omnil=src-sab
# //resultados.as.com/resultados/futbol/copa_del_rey/?omnil=src-sab
# //resultados.as.com/resultados/futbol/primera_femenina/jornada/?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/champions/?omnil=src-sab
# //resultados.as.com/resultados/futbol/europa_league/?omnil=src-sab
# //resultados.as.com/resultados/futbol/supercopa_europa/?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/inglaterra/?omnil=src-sab
# //resultados.as.com/resultados/futbol/alemania/?omnil=src-sab
# //resultados.as.com/resultados/futbol/italia/?omnil=src-sab
# //resultados.as.com/resultados/futbol/francia/?omnil=src-sab
# //resultados.as.com/resultados/futbol/portugal/?omnil=src-sab
# //resultados.as.com/resultados/futbol/holanda/?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/belgica/?omnil=src-sab
# //resultados.as.com/resultados/futbol/rumania/?omnil=src-sab
# //resultados.as.com/resultados/futbol/grecia/?omnil=src-sab
# //resultados.as.com/resultados/futbol/turquia/?omnil=src-sab
# //resultados.as.com/resultados/futbol/rusia/?omnil=src-sab
# //as.com/futbol/eurocopa.html?omnil=src-sab
# //resultados.as.com/resultados/futbol/eurocopa/2016/jornada/?omnil=src-sab
# //as.com/especiales/futbol/eurocopa/2020/guia/?omnil=src-sab
# //as.com/futbol/seleccion.html?omnil=src-sab
# //as.com/tag/eurocopa_2020/a/
# ?omnil=src-sab
# //resultados.as.com/resultados/ficha/equipo/espana/956/?omnil=src-sab
# //resultados.as.com/resultados/futbol/mundial/2018/calendario/grupos_b?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/argentina/2018_2019/?omnil=src-sab
# //resultados.as.com/resultados/futbol/colombia_i/?omnil=src-sab
# //resultados.as.com/resultados/futbol/colombia_ii/?omnil=src-sab
# //resultados.as.com/resultados/futbol/chile/?omnil=src-sab
# //as.com/futbol/mundial.html?omnil=src-sab
# //resultados.as.com/resultados/futbol/mundial/2018/calendario/dias/?omnil=src-sab
# //resultados.as.com/resultados/futbol/mundial/2018/jornada/?omnil=src-sab
# //resultados.as.com/resultados/futbol/mundial/2018/calendario/?omnil=src-sab
# //as.com/tag/c/32b48a114e9a9f1171f5318b78d6571f?omnil=src-sab
# //resultados.as.com/resultados/futbol/nations_league/?omnil=src-sab
# //resultados.as.com/resultados/futbol/nations_league/jornada/?omnil=src-sab
# //resultados.as.com/resultados/futbol/nations_league/calendario/?omnil=src-sab
# //resultados.as.com/resultados/futbol/nations_league/jornada/ligaa_4_1/?omnil=src-sab
# //resultados.as.com/resultados/futbol/nations_league/jornada/ligab_1_1/?omnil=src-sab
# //resultados.as.com/resultados/futbol/nations_league/jornada/ligac_3_1/?omnil=src-sab
# //resultados.as.com/resultados/futbol/nations_league/jornada/ligad_4_1/?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/confecup/?omnil=src-sab
# //resultados.as.com/resultados/futbol/mundial_clubes/?omnil=src-sab
# //as.com/tag/international_champions_cup/a/?omnil=src-sab
# //resultados.as.com/resultados/futbol/copa_africa/?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/copa_libertadores?omnil=src-sab
# //resultados.as.com/resultados/futbol/copa_sudamericana/?omnil=src-sab
# //resultados.as.com/resultados/futbol/copa_america/?omnil=src-sab
# //resultados.as.com/resultados/futbol/copa_oro_concacaf/?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/uruguay_apertura/?omnil=src-sab
# //resultados.as.com/resultados/futbol/torneo_descentralizado/?omnil=src-sab
# //resultados.as.com/resultados/futbol/venezuela_apertura/?omnil=src-sab
# //resultados.as.com/resultados/futbol/venezuela_clausura/?omnil=src-sab
# //resultados.as.com/resultados/?omnil=src-sab
# //resultados.as.com/resultados/futbol/mexico_apertura/?omnil=src-sab
# //resultados.as.com/resultados/futbol/mexico_clausura/?omnil=src-sab
# //resultados.as.com/resultados/futbol/mls/?omnil=src-sab
# //resultados.as.com/resultados/motor/?omnil=src-sab
# //resultados.as.com/resultados/motor/motogp/2019/calendario/?omnil=src-sab
# //resultados.as.com/resultados/motor/formula_1/?omnil=src-sab
# //resultados.as.com/resultados/motor/moto2/?omnil=src-sab
# //resultados.as.com/resultados/motor/moto3/?omnil=src-sab
# //resultados.as.com/resultados/baloncesto/?omnil=src-sab
# //as.com/baloncesto/acb.html?omnil=src-sab
# //resultados.as.com/resultados/baloncesto/nba/jornada/?omnil=src-sab
# //resultados.as.com/resultados/baloncesto/euroliga/?omnil=src-sab
# //resultados.as.com/resultados/baloncesto/eurocup/?omnil=src-sab
# //resultados.as.com/resultados/baloncesto/copa_del_rey/?omnil=src-sab
# //resultados.as.com/resultados/tenis/?omnil=src-sab
# //resultados.as.com/resultados/tenis/open_australia/?omnil=src-sab
# //resultados.as.com/resultados/tenis/roland_garros/?omnil=src-sab
# //resultados.as.com/resultados/tenis/wimbledon/?omnil=src-sab
# //resultados.as.com/resultados/tenis/us_open/?omnil=src-sab
# //resultados.as.com/resultados/tenis/copa_davis/?omnil=src-sab
# //as.com/tenis/masters_1000.html?omnil=src-sab
# http://usuarios.as.com/newsletters/
# http://suscripciones.as.com/
# https://as.com/?nrd=1
# https://chile.as.com/chile/?nrd=1
# https://colombia.as.com/colombia/?nrd=1
# https://mexico.as.com/mexico/?nrd=1
# https://us.as.com/us/?nrd=1
# https://argentina.as.com/argentina/?nrd=1
# https://peru.as.com/peru/?nrd=1
# //en.as.com/en/?nrd=1
# //as.com/diarioas/america.html?nrd=1
# http://arabia.as.com
# //resultados.as.com/resultados/
# //resultados.as.com/resultados/
# #
# //resultados.as.com/resultados/futbol/tercera/
# //resultados.as.com/resultados/futbol/segunda_b/
# //resultados.as.com/resultados/futbol/primera_femenina/jornada/
# //resultados.as.com/resultados/futbol/segunda/
# //resultados.as.com/resultados/futbol/primera/
# //resultados.as.com/resultados/futbol/copa_del_rey/
# #
# //resultados.as.com/resultados/futbol/supercopa_europa/
# //resultados.as.com/resultados/futbol/europa_league/
# //resultados.as.com/resultados/futbol/champions/
# #
# //resultados.as.com/resultados/futbol/portugal/
# //resultados.as.com/resultados/futbol/italia/
# //resultados.as.com/resultados/futbol/inglaterra/
# //resultados.as.com/resultados/futbol/holanda/
# //resultados.as.com/resultados/futbol/francia/
# //resultados.as.com/resultados/futbol/alemania/
# #
# //resultados.as.com/resultados/futbol/turquia/
# //resultados.as.com/resultados/futbol/rusia/
# //resultados.as.com/resultados/futbol/rumania/
# //resultados.as.com/resultados/futbol/grecia/
# //resultados.as.com/resultados/futbol/belgica/
# //as.com/futbol/eurocopa.html
# #
# //resultados.as.com/resultados/ficha/equipo/espana/956/
# //resultados.as.com/resultados/futbol/clasificacion_eurocopa/
# //resultados.as.com/resultados/futbol/eurocopa/
# #
# //resultados.as.com/resultados/futbol/colombia_ii/
# //resultados.as.com/resultados/futbol/argentina/calendario/
# //resultados.as.com/resultados/futbol/torneo_descentralizado/
# //resultados.as.com/resultados/futbol/chile/
# #
# //resultados.as.com/resultados/futbol/clasificacion_mundial_concacaf/
# //resultados.as.com/resultados/futbol/clasificacion_mundial_africa/
# //resultados.as.com/resultados/futbol/clasificacion_mundial_sudamerica/
# //resultados.as.com/resultados/futbol/clasificacion_mundial_oceania/
# //resultados.as.com/resultados/futbol/clasificacion_mundial_europa/
# //resultados.as.com/resultados/futbol/clasificacion_mundial_asia/
# //resultados.as.com/resultados/futbol/nations_league/
# #
# //resultados.as.com/resultados/futbol/mundial_clubes/
# //as.com/tag/international_champions_cup/a/
# //resultados.as.com/resultados/futbol/confecup/
# #
# //resultados.as.com/resultados/futbol/copa_sudamericana/
# //resultados.as.com/resultados/futbol/copa_oro_concacaf/
# //resultados.as.com/resultados/futbol/copa_libertadores
# //resultados.as.com/resultados/futbol/copa_america/
# #
# //resultados.as.com/resultados/futbol/venezuela_clausura/
# //resultados.as.com/resultados/futbol/venezuela_apertura/
# //resultados.as.com/resultados/futbol/uruguay_apertura/
# //resultados.as.com/resultados/futbol/uruguay_clausura/
# //resultados.as.com/resultados/futbol/brasil/
# //resultados.as.com/resultados/futbol/paulista/
# #
# //resultados.as.com/resultados/futbol/mls/
# //resultados.as.com/resultados/futbol/mexico_clausura/
# //resultados.as.com/resultados/futbol/ecuador/
# //as.com/tag/liga_mexico_apertura/a/
# #
# //resultados.as.com/resultados/motor/motogp/2019/calendario/
#
# #
# //resultados.as.com/resultados/baloncesto/acb/
# //resultados.as.com/resultados/baloncesto/euroliga/jornada/
# //resultados.as.com/resultados/baloncesto/eurocup/jornada/
# //resultados.as.com/resultados/baloncesto/copa_del_rey/2016/
# #
# //resultados.as.com/resultados/tenis/wimbledon/
# //resultados.as.com/resultados/tenis/us_open/
# //resultados.as.com/resultados/tenis/roland_garros/
# //resultados.as.com/resultados/tenis/open_australia/
# //resultados.as.com/resultados/tenis/copa_davis/
# /resultados/2020/03/30/
# /resultados/2020/04/01/
# /resultados/2020/03/30/
# /resultados/2020/03/31/
# /resultados/2020/04/01/
# #
# #
# javascript:;
# javascript:;
# #
# #futbol_amistosos
# #futbol_clasificacion_eurocopa
# /resultados/futbol/
# /resultados/futbol/amistosos/2019/calendario/
# /resultados/futbol/amistosos/2019/calendario/
# /resultados/futbol/amistosos/2019/jornada/amistosos_a_1
# /resultados/ficha/equipo/alemania/1894/
# /resultados/futbol/amistosos/2019/directo/amistosos_a_1_310588/
# /resultados/ficha/equipo/italia/1890/
# /resultados/futbol/amistosos/2019/directo/amistosos_a_1_310588/
# /resultados/ficha/equipo/francia/961/
# /resultados/futbol/amistosos/2019/directo/amistosos_a_1_310635/
# /resultados/ficha/equipo/finlandia/1903/
# /resultados/futbol/amistosos/2019/directo/amistosos_a_1_310635/
# /resultados/futbol/clasificacion_eurocopa/2020/calendario/
# /resultados/futbol/clasificacion_eurocopa/2020/calendario/
# /resultados/futbol/clasificacion_eurocopa/2020/jornada/repesca_final_a_1
#
# /resultados/futbol/clasificacion_eurocopa/2020/directo/repesca_final_a_1_310193/
#
# /resultados/futbol/clasificacion_eurocopa/2020/directo/repesca_final_a_1_310193/
#
# /resultados/futbol/clasificacion_eurocopa/2020/directo/repesca_final_b_1_310194/
#
# /resultados/futbol/clasificacion_eurocopa/2020/directo/repesca_final_b_1_310194/
# #
# #futbol_amistosos
# #futbol_clasificacion_mundial_asia
# #futbol_clasificacion_mundial_sudamerica
# /resultados/futbol/
# /resultados/futbol/amistosos/calendario/
# /resultados/futbol/amistosos/calendario/
# /resultados/futbol/amistosos/2019/jornada/amistosos_a_1/
# /resultados/ficha/equipo/t_y_tobago/2978/
# /resultados/ficha/equipo/estonia/1891/
# /resultados/ficha/equipo/lituania/2723/
# /resultados/ficha/equipo/moldavia/2719/
# /resultados/ficha/equipo/rusia/1892/
# /resultados/ficha/equipo/chipre/2718/
# /resultados/ficha/equipo/suecia/1906/
# /resultados/ficha/equipo/letonia/2721/
# /resultados/ficha/equipo/san_marino/2526/
# /resultados/ficha/equipo/polonia/1902/
# /resultados/ficha/equipo/ucrania/2725/
# /resultados/ficha/equipo/inglaterra/1889/
# /resultados/ficha/equipo/dinamarca/1899/
# /resultados/futbol/clasificacion_mundial_asia/calendario/
# /resultados/futbol/clasificacion_mundial_asia/calendario/
# /resultados/futbol/clasificacion_mundial_asia/2019/jornada/segunda_fase_a_8/
# /resultados/ficha/equipo/australia/2100/
# /resultados/ficha/equipo/corea_del_sur/2086/
# /resultados/ficha/equipo/japon/1187/
# /resultados/ficha/equipo/iran/2088/
# /resultados/ficha/equipo/arabia_saudi/2084/
# /resultados/ficha/equipo/uzbekistan/2984/
# /resultados/ficha/equipo/qatar/2539/
# /resultados/futbol/clasificacion_mundial_sudamerica/calendario/
# /resultados/futbol/clasificacion_mundial_sudamerica/calendario/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/jornada/regular_a_2/
# /resultados/ficha/equipo/peru/1429/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310932/
# /resultados/ficha/equipo/brasil/1881/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310932/
# /resultados/ficha/equipo/chile/2077/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310935/
# /resultados/ficha/equipo/colombia/2087/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310935/
# /resultados/ficha/equipo/bolivia/1905/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310933/
# /resultados/ficha/equipo/argentina/1879/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310933/
# /resultados/ficha/equipo/ecuador/1887/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310934/
# /resultados/ficha/equipo/uruguay/1901/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310934/
# /resultados/ficha/equipo/venezuela/2930/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310931/
# /resultados/ficha/equipo/paraguay/1916/
# /resultados/futbol/clasificacion_mundial_sudamerica/2019/directo/regular_a_2_310931/
# javascript:void(0);
# javascript:void(0);
# https://as.com/?nrd=1
# https://chile.as.com/chile/?nrd=1
# https://colombia.as.com/colombia/?nrd=1
# https://mexico.as.com/mexico/?nrd=1
# https://us.as.com/us/?nrd=1
# https://argentina.as.com/argentina/?nrd=1
# https://peru.as.com/peru/?nrd=1
# https://as.com/diarioas/america.html?nrd=1
# https://en.as.com/en/?nrd=1
# https://arabia.as.com
# https://as.com/movil/app_as.html
# https://www.facebook.com/as
# https://twitter.com/diarioas
# https://www.youtube.com/DIARIOAScom
# https://www.instagram.com/diarioas/
# https://as.com/formularios/contacto.pl
# https://as.com/diarioas/aviso_legal.html
# https://as.com/diarioas/politica_privacidad.html
# https://www.prisa.com/es/info/politica-de-cookies-publi
# https://www.prisabs.com/uploads/2019/04/as-tarifas2019.pdf
# https://as.com/pdf/Condiciones_Generales_Suscripciones_DIARIO_AS.pdf
# https://www.prisa.com/es
# javascript:void(0);
# https://elpais.com/
# https://los40.com
# https://www.santillana.com/
# https://santillanacompartir.com/
# https://tvi.iol.pt/
# https://cadenaser.com
# https://as.com/
# http://www.adnradio.cl
# http://caracol.com.co/
# https://www.huffingtonpost.es/
# https://mx.unoi.com/
# http://wradio.com.mx/
# https://cincodias.elpais.com/
# http://www.continental.com.ar
# https://elpais.com/elpais/eps.html
# https://verne.elpais.com/
# https://www.cadenadial.com/
# https://play.kebuena.es/
# https://www.podiumpodcast.com/
# http://www.richmondelt.com/
# https://www.moderna.com.br/pagina-inicial.htm
# http://pluralportugal.pt/
# https://tvi24.iol.pt/
# https://elpais.com/elpais/icon.html
# https://smoda.elpais.com/
# https://www.loqueleo.com/
# https://as.com/meristation/
# https://elpais.com/elpais/planeta_futuro.html
# http://radiocomercial.iol.pt/
# javascript:void(0);
# https://www.santillana.com/
# http://www.santillana.com.ar
# https://santillana.com.bo/
# https://www.santillana.com.br/portal-santillana.htm
# https://santillana.cl/
# https://santillana.com.co/
# https://santillana.cr/
# https://santillana.com.ec/
# https://santillana.com.sv/
# https://santillana.es/
# https://santillana.com.gt/
# https://santillana.com.hn/
# https://www.santillana.com.mx/
# https://santillana.com.pa/
# http://www.santillana.com.py/
# https://santillana.com.pe/
# https://www.santillana.pt/
# http://santillana.com.pr/
# https://santillana.com.do/
# https://santillana.com.uy/
# http://www.santillana.com.ve/
# https://www.loqueleo.com/
# http://www.richmondelt.com/
# http://www.santillanafrancais.com/
# https://mx.unoi.com/
# https://santillanacompartir.com/
# https://ineverycrea.net/comunidad/ineverycrea
# https://www.bejob.com/
# https://www.fundacaosantillana.org.br/
# http://www.fundacionsantillana.com/
# http://www.fundacionsantillana.com/paises/colombia/
# http://www.periodismocultural.es/
# http://www.foroindustriasculturales.org/
# http://www.essayandscience.com
# https://www.premiovivalectura.org.ar/
# http://www.elboomeran.com/
# https://www.prisa.com/es/info/noticias
# https://elpais.com/
# https://elpais.com/elpais/portada_america.html?nrd=1
# https://brasil.elpais.com/?nrd=1
# https://cat.elpais.com/?nrd=1
# https://elpais.com/elpais/inenglish.html
# https://elpais.com/elpais/videos.html
# https://elpais.com/cultura/babelia.html
# https://elpais.com/elpais/blogs.html
# https://elpais.com/elpais/buenavida.html
# https://colecciones.elpais.com/
# https://servicios.elpais.com/clasificados/
# https://descuentos.elpais.com/
# https://cursos.elpais.com/
# https://elcomidista.elpais.com/
# https://elviajero.elpais.com/
# http://suscripciones.elpais.com/
# https://elpais.com/elpais/eps.html
# https://www.elpaisviajes.com/
# https://motor.elpais.com/
# https://elpais.com/elpais/escaparate.html
# https://escuela.elpais.com/
# https://elpais.com/elpais/icon.html
# https://elpais.com/elpais/icon_design.html
# https://juegos.elpais.com/?arkpromo=Footer
# https://librotea.elpais.com/
# https://elpais.com/elpais/planeta_futuro.html
# https://verne.elpais.com/
# https://retina.elpais.com/
# https://smoda.elpais.com/
# https://servicios.elpais.com/sorteos/
# https://as.com/?nrd=1
# https://as.com/diarioas/america.html?nrd=1
# https://arabia.as.com/?nrd=1
# https://argentina.as.com/?nrd=1
# https://chile.as.com/?nrd=1
# https://colombia.as.com/?nrd=1
# https://en.as.com/?nrd=1
# https://mexico.as.com/?nrd=1
# https://peru.as.com/?nrd=1
# https://us.as.com/?nrd=1
# https://resultados.as.com/resultados/
# https://as.com/videos/
# https://as.com/tikitakas/
# https://as.com/epik/
# https://as.com/meristation/betech.html
# https://as.com/showroom/
# https://as.com/diarioas/promociones.html
# https://as.com/diarioas/concursos.html
# https://asventajas.com/
# https://cincodias.elpais.com/
# https://cincodias.elpais.com/seccion/companias
# https://cincodias.elpais.com/seccion/mercados
# https://cincodias.elpais.com/seccion/economia
# https://cincodias.elpais.com/seccion/midinero
# https://cincodias.elpais.com/seccion/fortunas
# https://cincodias.elpais.com/mercados/
# https://cincodias.elpais.com/smartlife
# https://cincodias.elpais.com/territorio_pyme
# https://cincodias.elpais.com/agr/legal
# https://www.huffingtonpost.es/
# https://as.com/meristation/
# https://as.com/meristation/mexico.html
# https://www.prisa.com/es/info/radio
# http://www.adnradio.cl/
# https://cadenaser.com/
# http://caracol.com.co/
# http://envivo.caracol1260.com/
# http://www.continental.com.ar/
# http://www.radiopanama.com.pa/
# http://www.wradio.com.co/
# http://wradio.com.mx/
# http://www.wdeportes.com/
# http://los40.com.ar/
# http://los40.cl/
# http://los40.com.co/
# http://los40.co.cr/
# https://los40.com
# http://los40.com.mx/
# http://los40.com.pa/
# http://www.los40.com.py/
# http://www.los40.do/
# https://los40.com/seccion/los40classic/
# https://los40.com/seccion/los40dance/
# http://www.besame.fm/
# http://www.besame.com.pa/
# https://www.cadenadial.com/
# https://www.concierto.cl/
# https://www.corazon.cl/
# https://www.fmdos.cl/
# https://www.futuro.cl/
# https://play.kebuena.es/
# http://www.kebuena.com.mx/
# https://www.masmusica.com.pa/
# http://www.oxigeno.fm/
# http://www.pudahuel.cl/
# http://www.qhuboradio.com/
# http://www.radioacktiva.com/
# http://www.radioactiva.cl/
# https://www.radioimagina.cl/
# https://envivo.radiounochile.cl/
# https://www.radiole.com/
# https://www.rockandpop.cl/
# https://www.tropicanafm.com/bogota/
# http://www.planetevents.es/
# https://www.podiumpodcast.com/
# https://www.prisa.com/es/info/audiovisual
# https://www.mediacapital.pt/
# https://tvi.iol.pt/
# https://tvi24.iol.pt/
# https://tvi.iol.pt/internacional
# https://tvi.iol.pt/tvificcao
# https://tvi.iol.pt/tvireality
# https://tvi.iol.pt/tviafrica
# https://tviplayer.iol.pt/
# http://pluralportugal.pt/
# http://radiocomercial.iol.pt
# http://m80.iol.pt
# http://smoothfm.iol.pt/
# http://cidade.iol.pt/
# http://www.vodafone.fm/
# https://www.iol.pt/
# https://maisfutebol.iol.pt/
# https://autoportal.iol.pt/
# https://www.iol.pt/blogs
# https://www.iolnegocios.pt/
# https://www.prisa.com/es
# http://toyoutome.es/
# https://www.prisabs.com/es
# javascript:void(0);

# %%
# Web Scraping from Diario As.com
# Classification by team

from bs4 import BeautifulSoup
import requests 
import pandas as pd

# Cargar el html:

# URL donde se va hacer la operacion.
url = 'https://resultados.as.com/resultados/futbol/primera/clasificacion/'

# Descargar contenido de la pagina.
page = requests.get(url)

# Parse a forma to soup para poder identificar los
# diferentes formatos html
soup = BeautifulSoup(page.content,'html')

# Ahora identificamos los nombres de los equipos.
equipos = soup.find_all('span', class_ ='nombre-equipo')
# Ahora identificamos la puntuacion por equipos.
puntos = soup.find_all('td', class_ = 'destacado')

lista_equipos = list()
count = 0
for eq in equipos:
    if count < 20:
        lista_equipos.append(eq.text)
    else:
        break
    count +=1 
    
lista_puntos = list()
count = 0
for p in puntos:
    if count < 20:
        lista_puntos.append(p.text)
    else:
        break
    count +=1

# Creamos DataFrame Nombre, Puntos
df = pd.DataFrame({'Nombre':lista_equipos,'Putos':lista_puntos}, index=list(range(1,21)))
df
# Out:
#              Nombre Putos
# 1         Barcelona    58
# 2       Real Madrid    56
# 3           Sevilla    47
# 4       R. Sociedad    46
# 5            Getafe    46
# 6          Atlético    45
# 7          Valencia    42
# 8        Villarreal    38
# 9           Granada    38
# 10         Athletic    37
# 11          Osasuna    34
# 12            Betis    33
# 13          Levante    33
# 14           Alavés    32
# 15  Real Valladolid    29
# 16            Eibar    27
# 17            Celta    26
# 18         Mallorca    25
# 19          Leganés    23
# 20         Espanyol    20
